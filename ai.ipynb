# %%
import numpy as np
from PIL import Image

# %%
img1=Image.open("dog.avif")
matrix=np.array(img)

# %%
matrix
# Out:
# array([[[166, 188, 123],
#         [166, 188, 123],
#         [166, 188, 123],
#         ...,
#         [163, 184, 117],
#         [163, 184, 117],
#         [163, 184, 117]],
#
#        [[166, 188, 123],
#         [166, 188, 123],
#         [166, 188, 123],
#         ...,
#         [163, 184, 117],
#         [163, 184, 117],
#         [163, 184, 117]],
#
#        [[166, 188, 123],
#         [166, 188, 123],
#         [166, 188, 123],
#         ...,
#         [163, 184, 117],
#         [163, 184, 117],
#         [163, 184, 117]],
#
#        ...,
#
#        [[ 99, 122,  54],
#         [100, 123,  55],
#         [100, 123,  55],
#         ...,
#         [122, 125,  72],
#         [122, 125,  72],
#         [123, 126,  73]],
#
#        [[ 99, 122,  54],
#         [ 99, 122,  54],
#         [ 99, 122,  54],
#         ...,
#         [123, 126,  73],
#         [123, 126,  73],
#         [123, 126,  73]],
#
#        [[ 99, 122,  52],
#         [ 99, 122,  52],
#         [ 99, 122,  54],
# ...

# %%
img2=Image.open("twodogs.jpeg")
matrix=np.array(img)

# %%
matrix
# Out:
# array([[[ 74,  95,  56],
#         [ 74,  95,  56],
#         [ 74,  95,  56],
#         ...,
#         [ 71,  93,  55],
#         [ 71,  93,  55],
#         [ 71,  93,  55]],
#
#        [[ 74,  95,  56],
#         [ 74,  95,  56],
#         [ 74,  95,  56],
#         ...,
#         [ 71,  93,  55],
#         [ 71,  93,  55],
#         [ 71,  93,  55]],
#
#        [[ 74,  95,  56],
#         [ 74,  95,  56],
#         [ 74,  95,  56],
#         ...,
#         [ 71,  93,  55],
#         [ 71,  93,  55],
#         [ 71,  93,  55]],
#
#        ...,
#
#        [[ 81,  88,  54],
#         [ 81,  88,  54],
#         [ 81,  88,  54],
#         ...,
#         [125,  97,  50],
#         [125,  97,  50],
#         [125,  97,  50]],
#
#        [[ 81,  88,  54],
#         [ 81,  88,  54],
#         [ 81,  88,  54],
#         ...,
#         [127,  96,  50],
#         [127,  96,  50],
#         [127,  96,  50]],
#
#        [[ 81,  88,  54],
#         [ 81,  88,  54],
#         [ 81,  88,  54],
# ...

# %%
img1=np.array(Image.open("dog.avif").resize((200,200)))
img2=np.array(Image.open("twodogs.avif").resize((200,200)))

# %%
diff=np.mean(np.abs(img1-img2))
similarity=(1-diff/255)*100
print (similarity)
# Out:
# 70.65491830065359

# %%
img3=Image.open("suvaan.JPG")
matrix=np.array(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img3=Image.open(suvaan.JPG)
#       2 matrix=np.array(img)
#
# NameError: name 'Image' is not defined

# %%
img4=Image.open("suv.jpg")
matrix=np.array(img)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.6' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
img3=np.array(Image.open("suvaan.JPG").resize((200,200)))
img4=np.array(Image.open("suv.JPG").resize((200,200)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 img3=np.array(Image.open("suvaan.JPG").resize((200,200)))
#       2 img4=np.array(Image.open("suv.JPG").resize((200,200)))
#
# NameError: name 'np' is not defined
