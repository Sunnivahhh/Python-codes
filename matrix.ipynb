# %%
import numpy as np
from PIL import Image

# %%
img3=Image.open("suvaan.JPG")
matrix=np.array(img3)

# %%
matrix
# Out:
# array([[[62, 29, 20],
#         [63, 30, 21],
#         [64, 31, 22],
#         ...,
#         [43, 16,  9],
#         [43, 16,  9],
#         [44, 17, 10]],
#
#        [[63, 30, 21],
#         [63, 30, 21],
#         [64, 31, 22],
#         ...,
#         [43, 16,  9],
#         [43, 16,  9],
#         [44, 17, 10]],
#
#        [[64, 31, 22],
#         [64, 31, 22],
#         [65, 32, 23],
#         ...,
#         [44, 17, 10],
#         [44, 17, 10],
#         [45, 18, 11]],
#
#        ...,
#
#        [[66, 34, 21],
#         [66, 34, 21],
#         [65, 33, 20],
#         ...,
#         [81, 83, 72],
#         [80, 82, 71],
#         [80, 82, 71]],
#
#        [[66, 34, 21],
#         [65, 33, 20],
#         [65, 33, 20],
#         ...,
#         [75, 77, 64],
#         [74, 76, 63],
#         [74, 76, 63]],
#
#        [[65, 33, 20],
#         [65, 33, 20],
#         [64, 32, 19],
#         ...,
#         [69, 71, 58],
#         [69, 71, 58],
#         [70, 72, 59]]], dtype=uint8)

# %%
img4=Image.open("suv.JPG")
matrix=np.array(img4)

# %%
matrix
# Out:
# array([[[147, 146, 128],
#         [148, 145, 128],
#         [153, 152, 134],
#         ...,
#         [106, 102,  91],
#         [104, 100,  89],
#         [104, 100,  89]],
#
#        [[147, 146, 128],
#         [148, 145, 130],
#         [153, 152, 134],
#         ...,
#         [106, 102,  91],
#         [105, 101,  90],
#         [105, 101,  90]],
#
#        [[147, 146, 128],
#         [150, 144, 128],
#         [152, 151, 133],
#         ...,
#         [106, 102,  91],
#         [106, 102,  91],
#         [104, 100,  89]],
#
#        ...,
#
#        [[160, 153, 143],
#         [158, 151, 141],
#         [156, 149, 139],
#         ...,
#         [ 15,   9,  11],
#         [ 15,   9,  11],
#         [ 15,   9,  11]],
#
#        [[137, 130, 120],
#         [138, 131, 121],
#         [138, 131, 121],
#         ...,
#         [ 14,   8,  10],
#         [ 14,   8,  10],
#         [ 14,   8,  10]],
#
#        [[114, 105,  96],
#         [115, 106,  97],
#         [118, 109, 100],
#         ...,
#         [ 13,   7,   9],
#         [ 13,   7,   9],
#         [ 13,   7,   9]]], dtype=uint8)

# %%
img3=np.array(Image.open("suvaan.JPG").resize((200,200)))
img4=np.array(Image.open("suv.JPG").resize((200,200)))

# %%
diff=np.mean(np.abs(img3-img4))
similarity=(1-diff/255)*100
print (similarity)
# Out:
# 50.55297385620915
