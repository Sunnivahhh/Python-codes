# %%
import requests as rq
from bs4 import BeautifulSoup as bs
url="https://merolagani.com/CompanyDetail.aspx?symbol=nmb"
response=rq.get(url)
soup=bs(response.text,"html.parser")
random = soup.prettify()
print (soup.title.string)
# Out:
# 	merolagani - NMB Bank Limited (NMB) Detail, Announcements, News, Price History, Floorsheet

# %%
a="merolagani - NMB Bank Limited (NMB) Detail, Announcements, News, Price History, Floorsheet"
